# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data hasil evaluasi
data = {
    "Metode Evaluasi": [
        "Silhouette Score",
        "Davies-Bouldin Index",
        "Calinski-Harabasz Index",
        "Adjusted Rand Index"
    ],
    "KMeans": [0.5804, 0.3930, 1411.1887, None],
    "Agglomerative": [0.5797, 0.3958, 1407.7242, None],
    "KMeans vs Agglo": [None, None, None, 0.9435]
}
data_frame = pd.DataFrame(data)
data_frame.set_index("Metode Evaluasi", inplace=True)
data_frame
# Out:
#                             KMeans  Agglomerative  KMeans vs Agglo
# Metode Evaluasi
# Silhouette Score            0.5804         0.5797              NaN
# Davies-Bouldin Index        0.3930         0.3958              NaN
# Calinski-Harabasz Index  1411.1887      1407.7242              NaN
# Adjusted Rand Index            NaN            NaN           0.9435
